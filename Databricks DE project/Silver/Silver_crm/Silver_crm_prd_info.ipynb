# %%
# %sql
select * from  de_project.bronze_layer.crm_prd_info ;

# %% [markdown]
# - 1- Correct the column Abbriviation
# - 2- Remove the duplicates
# - 3- Remove the Null Values

# %% [markdown]
# # Read the Data from Bronze Layer
