# %%
# %sql
select * from de_project.bronze_layer.erp_cust ;

# %% [markdown]
# - 1-Correct the column abbriation
# - 2- Correct the BDate column into date of birth
# - 3- Remove the Duplicates and Null values

# %% [markdown]
# # Read the Data from Bronze Layer
